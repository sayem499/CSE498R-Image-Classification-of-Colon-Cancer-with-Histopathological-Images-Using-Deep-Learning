# %%
import splitfolders
from tensorflow import keras
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D,Flatten,Activation
from tensorflow.keras import regularizers

# %%
#input_folder = 'image_data/'

# %%
#splitfolders.ratio(input_folder,output="image_dataset",seed=42,ratio=(.7, .2, .1),group_prefix=None)

# %%
train_directory = 'image_dataset/train'
test_directory = 'image_dataset/test'
val_directory = 'image_dataset/val'

# %%
train_generator = ImageDataGenerator(rescale=1/255).flow_from_directory(
    train_directory,
    target_size=(224,224),
    color_mode='rgb',
    batch_size=64,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)
validation_generator = ImageDataGenerator(rescale=1/255).flow_from_directory(
    val_directory,
    target_size=(224,224),
    color_mode='rgb',
    batch_size=64,
    class_mode='categorical',
    shuffle=True,
    seed=42
   
    
)

test_generator = ImageDataGenerator(rescale=1/255).flow_from_directory(
test_directory,
target_size=(224,224), 
color_mode='rgb', 
batch_size=64, 
class_mode='categorical',    
shuffle=False
)
# Out:
# Found 2277 images belonging to 4 classes.
# Found 649 images belonging to 4 classes.
# Found 330 images belonging to 4 classes.

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size=(3,3), activation='relu',input_shape=(224,224,3)))
model.add(MaxPooling2D(3,3))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(3,3))
model.add(Conv2D(224, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(3,3))
model.add(Flatten())

model.add(Dense(16, kernel_regularizer=regularizers.l2(l2=0.01)))
model.add(Dense(4, activation='softmax'))

model.compile(optimizer=keras.optimizers.Adam(learning_rate=(0.001)),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)
history = model.fit(train_generator,
          steps_per_epoch=10,
          batch_size=64,
          epochs=30,
          callbacks=[rlrop],          
          validation_data=validation_generator
         )
# Out:
# Epoch 1/30
# 10/10 [==============================] - 27s 3s/step - loss: 1.5566 - accuracy: 0.3409 - val_loss: 1.4074 - val_accuracy: 0.3190 - lr: 0.0010
# Epoch 2/30
# 10/10 [==============================] - 26s 3s/step - loss: 1.2044 - accuracy: 0.5693 - val_loss: 0.9881 - val_accuracy: 0.7227 - lr: 0.0010
# Epoch 3/30
# 10/10 [==============================] - 26s 3s/step - loss: 0.8325 - accuracy: 0.7484 - val_loss: 0.8769 - val_accuracy: 0.7535 - lr: 0.0010
# Epoch 4/30
# 10/10 [==============================] - 23s 2s/step - loss: 0.7713 - accuracy: 0.7375 - val_loss: 0.7418 - val_accuracy: 0.7658 - lr: 0.0010
# Epoch 5/30
# 10/10 [==============================] - 23s 2s/step - loss: 0.6915 - accuracy: 0.7700 - val_loss: 0.6905 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 6/30
# 10/10 [==============================] - 27s 3s/step - loss: 0.6198 - accuracy: 0.7844 - val_loss: 0.7006 - val_accuracy: 0.7519 - lr: 0.0010
# Epoch 7/30
# 10/10 [==============================] - 27s 3s/step - loss: 0.5863 - accuracy: 0.8328 - val_loss: 0.7851 - val_accuracy: 0.7088 - lr: 0.0010
# Epoch 8/30
# 10/10 [==============================] - 34s 4s/step - loss: 0.5254 - accuracy: 0.8375 - val_loss: 0.6449 - val_accuracy: 0.7612 - lr: 0.0010
# Epoch 9/30
# 10/10 [==============================] - 25s 3s/step - loss: 0.4773 - accuracy: 0.8656 - val_loss: 0.5524 - val_accuracy: 0.8351 - lr: 0.0010
# Epoch 10/30
# 10/10 [==============================] - 24s 2s/step - loss: 0.5085 - accuracy: 0.8375 - val_loss: 0.5222 - val_accuracy: 0.8459 - lr: 0.0010
# Epoch 11/30
# 10/10 [==============================] - 24s 2s/step - loss: 0.4247 - accuracy: 0.8969 - val_loss: 0.5039 - val_accuracy: 0.8444 - lr: 0.0010
# Epoch 12/30
# 10/10 [==============================] - 24s 2s/step - loss: 0.4207 - accuracy: 0.8858 - val_loss: 0.4660 - val_accuracy: 0.8690 - lr: 0.0010
# Epoch 13/30
# 10/10 [==============================] - 23s 2s/step - loss: 0.3301 - accuracy: 0.9233 - val_loss: 0.4534 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 14/30
# 10/10 [==============================] - 24s 2s/step - loss: 0.3492 - accuracy: 0.9233 - val_loss: 0.4518 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 15/30
# 10/10 [==============================] - 28s 3s/step - loss: 0.3977 - accuracy: 0.8777 - val_loss: 0.6639 - val_accuracy: 0.7982 - lr: 0.0010
# Epoch 16/30
# 10/10 [==============================] - 27s 3s/step - loss: 0.4235 - accuracy: 0.8813 - val_loss: 0.5415 - val_accuracy: 0.8444 - lr: 0.0010
# Epoch 17/30
# 10/10 [==============================] - 26s 3s/step - loss: 0.3905 - accuracy: 0.8891 - val_loss: 0.5494 - val_accuracy: 0.8382 - lr: 0.0010
# Epoch 18/30
# 10/10 [==============================] - 30s 3s/step - loss: 0.3325 - accuracy: 0.9109 - val_loss: 0.4304 - val_accuracy: 0.8767 - lr: 0.0010
# Epoch 19/30
# 10/10 [==============================] - 27s 3s/step - loss: 0.3151 - accuracy: 0.9250 - val_loss: 0.4407 - val_accuracy: 0.8706 - lr: 0.0010
# Epoch 20/30
# 10/10 [==============================] - 24s 2s/step - loss: 0.2851 - accuracy: 0.9312 - val_loss: 0.4676 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 21/30
# 10/10 [==============================] - 24s 2s/step - loss: 0.3018 - accuracy: 0.9359 - val_loss: 0.4701 - val_accuracy: 0.8582 - lr: 0.0010
# Epoch 22/30
# 10/10 [==============================] - 25s 3s/step - loss: 0.2816 - accuracy: 0.9281 - val_loss: 0.4094 - val_accuracy: 0.8860 - lr: 0.0010
# Epoch 23/30
# 10/10 [==============================] - 28s 3s/step - loss: 0.2423 - accuracy: 0.9494 - val_loss: 0.3757 - val_accuracy: 0.9029 - lr: 0.0010
# Epoch 24/30
# 10/10 [==============================] - 28s 3s/step - loss: 0.2817 - accuracy: 0.9359 - val_loss: 0.3960 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 25/30
# 10/10 [==============================] - 26s 3s/step - loss: 0.2449 - accuracy: 0.9429 - val_loss: 0.4212 - val_accuracy: 0.8659 - lr: 0.0010
# Epoch 26/30
# 10/10 [==============================] - 27s 3s/step - loss: 0.2836 - accuracy: 0.9438 - val_loss: 0.4388 - val_accuracy: 0.8737 - lr: 0.0010
# Epoch 27/30
# 10/10 [==============================] - 30s 3s/step - loss: 0.3263 - accuracy: 0.9016 - val_loss: 0.4419 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 28/30
# 10/10 [==============================] - 29s 3s/step - loss: 0.3256 - accuracy: 0.9187 - val_loss: 0.5616 - val_accuracy: 0.8290 - lr: 0.0010
# Epoch 29/30
# 10/10 [==============================] - 28s 3s/step - loss: 0.2928 - accuracy: 0.9203 - val_loss: 0.3805 - val_accuracy: 0.8998 - lr: 0.0010
# Epoch 30/30
# 10/10 [==============================] - 28s 3s/step - loss: 0.2250 - accuracy: 0.9516 - val_loss: 0.3598 - val_accuracy: 0.9106 - lr: 0.0010

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Train & Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Train & Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper right')
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 3s 539ms/step - loss: 0.3523 - accuracy: 0.9303
# [0.35230493545532227, 0.9303030371665955]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

pred = model.predict(test_generator)
pred_classes = [np.argmax(element) for element in pred]

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

report = classification_report(true_classes, pred_classes, target_names = class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.96      0.83      0.89        52
#        Early       0.88      0.96      0.92        99
#          Pre       0.96      0.90      0.93        97
#          Pro       0.95      1.00      0.98        82
#
#     accuracy                           0.93       330
#    macro avg       0.94      0.92      0.93       330
# weighted avg       0.93      0.93      0.93       330
