# %%
import splitfolders
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D,Flatten,Activation
from tensorflow.keras import regularizers

# %%
#input_folder = 'image_data/'

# %%
#splitfolders.ratio(input_folder,output="image_dataset",seed=42,ratio=(.7, .2, .1),group_prefix=None)

# %%
train_directory = 'image_dataset/train'
test_directory = 'image_dataset/test'
val_directory = 'image_dataset/val'

# %%
train_generator = ImageDataGenerator(rescale=1/255).flow_from_directory(
    train_directory,
    target_size=(224,224),
    color_mode='rgb',
    batch_size=64,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)
validation_generator = ImageDataGenerator(rescale=1/255).flow_from_directory(
    val_directory,
    target_size=(224,224),
    color_mode='rgb',
    batch_size=64,
    class_mode='categorical',
    shuffle=True,
    seed=42
)

test_generator = ImageDataGenerator(rescale=1/255).flow_from_directory(
test_directory,
target_size=(224,224), 
color_mode='rgb', 
batch_size=64, 
class_mode='categorical',    
shuffle=False
)
# Out:
# Found 2277 images belonging to 4 classes.
# Found 649 images belonging to 4 classes.
# Found 330 images belonging to 4 classes.

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size=(3,3), activation='relu',input_shape=(224,224,3)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(224, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())

model.add(Dense(16, kernel_regularizer=regularizers.l2(l2=0.001)))
model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_generator,
          steps_per_epoch=10,
          epochs=30,
          validation_data=validation_generator
         )
# Out:
# Epoch 1/30
# 10/10 [==============================] - 64s 6s/step - loss: 1.8842 - accuracy: 0.3562 - val_loss: 1.3690 - val_accuracy: 0.5085
# Epoch 2/30
# 10/10 [==============================] - 65s 7s/step - loss: 1.2006 - accuracy: 0.5703 - val_loss: 1.0329 - val_accuracy: 0.7149
# Epoch 3/30
# 10/10 [==============================] - 62s 6s/step - loss: 0.8901 - accuracy: 0.6891 - val_loss: 0.7686 - val_accuracy: 0.7504
# Epoch 4/30
# 10/10 [==============================] - 63s 6s/step - loss: 0.6903 - accuracy: 0.7609 - val_loss: 0.7156 - val_accuracy: 0.7165
# Epoch 5/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.6200 - accuracy: 0.7625 - val_loss: 0.6818 - val_accuracy: 0.7257
# Epoch 6/30
# 10/10 [==============================] - 61s 6s/step - loss: 0.5784 - accuracy: 0.7618 - val_loss: 0.6645 - val_accuracy: 0.7658
# Epoch 7/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.5225 - accuracy: 0.8031 - val_loss: 0.6372 - val_accuracy: 0.7165
# Epoch 8/30
# 10/10 [==============================] - 66s 7s/step - loss: 0.4994 - accuracy: 0.8281 - val_loss: 0.6774 - val_accuracy: 0.7242
# Epoch 9/30
# 10/10 [==============================] - 65s 7s/step - loss: 0.4853 - accuracy: 0.8484 - val_loss: 0.6284 - val_accuracy: 0.7612
# Epoch 10/30
# 10/10 [==============================] - 64s 7s/step - loss: 0.4045 - accuracy: 0.8453 - val_loss: 0.6487 - val_accuracy: 0.7535
# Epoch 11/30
# 10/10 [==============================] - 62s 6s/step - loss: 0.3831 - accuracy: 0.8719 - val_loss: 0.6784 - val_accuracy: 0.7473
# Epoch 12/30
# 10/10 [==============================] - 62s 6s/step - loss: 0.4036 - accuracy: 0.8672 - val_loss: 0.6309 - val_accuracy: 0.7812
# Epoch 13/30
# 10/10 [==============================] - 62s 6s/step - loss: 0.3401 - accuracy: 0.9000 - val_loss: 0.6485 - val_accuracy: 0.7858
# Epoch 14/30
# 10/10 [==============================] - 62s 6s/step - loss: 0.3862 - accuracy: 0.8719 - val_loss: 0.7674 - val_accuracy: 0.7781
# Epoch 15/30
# 10/10 [==============================] - 64s 7s/step - loss: 0.3209 - accuracy: 0.8859 - val_loss: 0.7376 - val_accuracy: 0.7535
# Epoch 16/30
# 10/10 [==============================] - 70s 7s/step - loss: 0.3420 - accuracy: 0.8953 - val_loss: 0.6907 - val_accuracy: 0.7843
# Epoch 17/30
# 10/10 [==============================] - 69s 7s/step - loss: 0.2943 - accuracy: 0.9135 - val_loss: 0.7225 - val_accuracy: 0.7612
# Epoch 18/30
# 10/10 [==============================] - 64s 7s/step - loss: 0.2291 - accuracy: 0.9484 - val_loss: 0.6959 - val_accuracy: 0.7904
# Epoch 19/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.2320 - accuracy: 0.9500 - val_loss: 0.6270 - val_accuracy: 0.7997
# Epoch 20/30
# 10/10 [==============================] - 62s 6s/step - loss: 0.2079 - accuracy: 0.9625 - val_loss: 0.6202 - val_accuracy: 0.8012
# Epoch 21/30
# 10/10 [==============================] - 72s 7s/step - loss: 0.2030 - accuracy: 0.9625 - val_loss: 0.6116 - val_accuracy: 0.7951
# Epoch 22/30
# 10/10 [==============================] - 68s 7s/step - loss: 0.1730 - accuracy: 0.9625 - val_loss: 0.6714 - val_accuracy: 0.7997
# Epoch 23/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.1460 - accuracy: 0.9688 - val_loss: 0.8591 - val_accuracy: 0.7982
# Epoch 24/30
# 10/10 [==============================] - 70s 7s/step - loss: 0.1920 - accuracy: 0.9625 - val_loss: 0.7339 - val_accuracy: 0.7673
# Epoch 25/30
# 10/10 [==============================] - 66s 7s/step - loss: 0.1489 - accuracy: 0.9781 - val_loss: 0.7066 - val_accuracy: 0.7951
# Epoch 26/30
# 10/10 [==============================] - 70s 7s/step - loss: 0.1268 - accuracy: 0.9821 - val_loss: 0.7657 - val_accuracy: 0.7889
# Epoch 27/30
# 10/10 [==============================] - 69s 7s/step - loss: 0.1562 - accuracy: 0.9788 - val_loss: 0.8739 - val_accuracy: 0.7519
# Epoch 28/30
# 10/10 [==============================] - 70s 7s/step - loss: 0.1648 - accuracy: 0.9641 - val_loss: 0.7400 - val_accuracy: 0.7827
# Epoch 29/30
# 10/10 [==============================] - 72s 7s/step - loss: 0.1247 - accuracy: 0.9766 - val_loss: 0.6879 - val_accuracy: 0.8074
# Epoch 30/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.1078 - accuracy: 0.9853 - val_loss: 0.6884 - val_accuracy: 0.8182

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('aloss')
plt.xlabel('epoch')
plt.legend(['train'],loc='upper right')
plt.show()

# %%
plt.plot(history.history['val_accuracy'])
plt.title('Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['validation'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['validation'],loc='upper right')
plt.show()
