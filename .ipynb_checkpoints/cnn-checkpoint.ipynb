# %%
import splitfolders
import cv2
from tensorflow import keras
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout, Dense, Conv2D, MaxPooling2D,Flatten,Activation
from tensorflow.keras import regularizers

# %%
#input_folder = 'image_data/'
#splitfolders.ratio(input_folder,output="image_dataset",seed=42,ratio=(.7, .2, .1),group_prefix=None)

# %%
img=cv2.imread("image_dataset/train/colon_aca/colonca1.jpeg")
img.shape
# Out:
# (768, 768, 3)

# %%
train_directory = 'image_dataset/train'
test_directory = 'image_dataset/test'
val_directory = 'image_dataset/val'

# %%
train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
    train_directory,
    target_size=(224,224),
    color_mode='rgb',
    batch_size=150,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)
validation_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
    val_directory,
    target_size=(224,224),
    color_mode='rgb',
    batch_size=150,
    class_mode='categorical',
    shuffle=True,
    seed=42
   
    
)

test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
test_directory,
target_size=(224,224), 
color_mode='rgb', 
batch_size=150, 
class_mode='categorical',    
shuffle=False
)
# Out:
# Found 7000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(4,4), activation='relu',input_shape=(224,224,3)))
model.add(MaxPooling2D(4,4))
model.add(Conv2D(64, kernel_size=(4,4), activation='relu'))
model.add(MaxPooling2D(4,4))
model.add(Conv2D(128, kernel_size=(4,4), activation='relu'))
model.add(MaxPooling2D(4,4))


model.add(Flatten())
model.add(Dense(32, kernel_regularizer=regularizers.l2(l2=0.001)))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.001),loss='categorical_crossentropy',metrics=['accuracy'])
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)
history = model.fit(train_generator,
                    steps_per_epoch=10,
                    epochs=30,
                    callbacks=[rlrop],          
                    validation_data=validation_generator,
                    validation_steps=3)
# Out:
# Epoch 1/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.7613 - accuracy: 0.5133 - val_loss: 0.7419 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/30
# 10/10 [==============================] - 67s 7s/step - loss: 0.7337 - accuracy: 0.5760 - val_loss: 0.7184 - val_accuracy: 0.6067 - lr: 0.0010
# Epoch 3/30
# 10/10 [==============================] - 63s 6s/step - loss: 0.7125 - accuracy: 0.5707 - val_loss: 0.7017 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 4/30
# 10/10 [==============================] - 60s 6s/step - loss: 0.6506 - accuracy: 0.6503 - val_loss: 0.6438 - val_accuracy: 0.6867 - lr: 0.0010
# Epoch 5/30
# 10/10 [==============================] - 68s 7s/step - loss: 0.5928 - accuracy: 0.7133 - val_loss: 0.5252 - val_accuracy: 0.8178 - lr: 0.0010
# Epoch 6/30
# 10/10 [==============================] - 57s 6s/step - loss: 0.5353 - accuracy: 0.7745 - val_loss: 0.4755 - val_accuracy: 0.8089 - lr: 0.0010
# Epoch 7/30
# 10/10 [==============================] - 57s 6s/step - loss: 0.4692 - accuracy: 0.8014 - val_loss: 0.5825 - val_accuracy: 0.7556 - lr: 0.0010
# Epoch 8/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.4951 - accuracy: 0.7673 - val_loss: 0.4685 - val_accuracy: 0.8067 - lr: 0.0010
# Epoch 9/30
# 10/10 [==============================] - 57s 6s/step - loss: 0.5111 - accuracy: 0.7634 - val_loss: 0.4631 - val_accuracy: 0.8444 - lr: 0.0010
# Epoch 10/30
# 10/10 [==============================] - 58s 6s/step - loss: 0.4001 - accuracy: 0.8614 - val_loss: 0.3862 - val_accuracy: 0.8533 - lr: 0.0010
# Epoch 11/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.4158 - accuracy: 0.8280 - val_loss: 0.3654 - val_accuracy: 0.8622 - lr: 0.0010
# Epoch 12/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.4115 - accuracy: 0.8267 - val_loss: 0.3397 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 13/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.3191 - accuracy: 0.8940 - val_loss: 0.2994 - val_accuracy: 0.9067 - lr: 0.0010
# Epoch 14/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.2862 - accuracy: 0.9007 - val_loss: 0.2981 - val_accuracy: 0.8822 - lr: 0.0010
# Epoch 15/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.3206 - accuracy: 0.8760 - val_loss: 0.2870 - val_accuracy: 0.8867 - lr: 0.0010
# Epoch 16/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.3192 - accuracy: 0.8793 - val_loss: 0.2841 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 17/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.3171 - accuracy: 0.8693 - val_loss: 0.2772 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 18/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.3387 - accuracy: 0.8667 - val_loss: 0.4035 - val_accuracy: 0.8178 - lr: 0.0010
# Epoch 19/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.3141 - accuracy: 0.8680 - val_loss: 0.2599 - val_accuracy: 0.9067 - lr: 0.0010
# Epoch 20/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.2491 - accuracy: 0.9067 - val_loss: 0.3529 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 21/30
# 10/10 [==============================] - 58s 6s/step - loss: 0.2627 - accuracy: 0.8947 - val_loss: 0.2302 - val_accuracy: 0.9222 - lr: 0.0010
# Epoch 22/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.2598 - accuracy: 0.8980 - val_loss: 0.3256 - val_accuracy: 0.8622 - lr: 0.0010
# Epoch 23/30
# 10/10 [==============================] - 60s 6s/step - loss: 0.3162 - accuracy: 0.8720 - val_loss: 0.2427 - val_accuracy: 0.9089 - lr: 0.0010
# Epoch 24/30
# 10/10 [==============================] - 57s 6s/step - loss: 0.2443 - accuracy: 0.9117 - val_loss: 0.2330 - val_accuracy: 0.9067 - lr: 0.0010
# Epoch 25/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.2246 - accuracy: 0.9240 - val_loss: 0.2013 - val_accuracy: 0.9356 - lr: 0.0010
# Epoch 26/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.2055 - accuracy: 0.9333 - val_loss: 0.2315 - val_accuracy: 0.9133 - lr: 0.0010
# Epoch 27/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.2522 - accuracy: 0.9007 - val_loss: 0.3208 - val_accuracy: 0.8733 - lr: 0.0010
# Epoch 28/30
# 10/10 [==============================] - 57s 6s/step - loss: 0.2240 - accuracy: 0.9159 - val_loss: 0.2237 - val_accuracy: 0.9133 - lr: 0.0010
# Epoch 29/30
# 10/10 [==============================] - 59s 6s/step - loss: 0.1817 - accuracy: 0.9380 - val_loss: 0.1818 - val_accuracy: 0.9289 - lr: 0.0010
# Epoch 30/30
# 10/10 [==============================] - 58s 6s/step - loss: 0.1798 - accuracy: 0.9340 - val_loss: 0.2210 - val_accuracy: 0.9089 - lr: 0.0010

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Train & Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Train & Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper right')
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 15s 2s/step - loss: 0.2057 - accuracy: 0.9140
# [0.20571598410606384, 0.9139999747276306]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns

pred = model.predict(test_generator)
pred_classes = [np.argmax(element) for element in pred]
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

sns.heatmap(confusion_matrix(true_classes,pred_classes), annot = True)



report = classification_report(true_classes, pred_classes, target_names = class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#    colon_aca       1.00      0.83      0.91       500
#      colon_n       0.85      1.00      0.92       500
#
#     accuracy                           0.91      1000
#    macro avg       0.93      0.91      0.91      1000
# weighted avg       0.93      0.91      0.91      1000
